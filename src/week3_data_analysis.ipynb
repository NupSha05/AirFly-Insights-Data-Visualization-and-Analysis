# %% [markdown]
# # WEEK 3 : EXPLORATORY ANALYSIS - UNIVARIATE AND BIVARIATE ANALYSIS

# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")
plt.rcParams["figure.figsize"]=(10,6)

# %% [markdown]
# Load Data

# %%
df = pd.read_csv("../data/processed/week2_processed.csv")

print(df.shape)
df.head()
# Out:
# (98619, 31)
#   Passenger_ID First_Name Last_Name Passenger_Full_Name  Gender  Age  \
# 0       ABVWIg     Edithe    Leggis       Edithe Leggis  Female   62
# 1       jkXXAX     Elwood      Catt         Elwood Catt    Male   62
# 2       CdUz2g      Darby   Felgate       Darby Felgate    Male   67
# 3       BRS38V   Dominica      Pyle       Dominica Pyle  Female   71
# 4       9kvTLo        Bay   Pencost         Bay Pencost    Male   21
#
#         Age_Group Nationality               Airport_Name Airport_Country_Code  \
# 0  Senior Citizen       Japan           Coldfoot Airport                   US
# 1  Senior Citizen   Nicaragua          Kugluktuk Airport                   CA
# 2  Senior Citizen      Russia     Grenoble-Isère Airport                   FR
# 3  Senior Citizen       China  Ottawa / Gatineau Airport                   CA
# 4           Youth       China            Gillespie Field                   US
#
#    ... Weekly_Traffic Arrival_Airport           Pilot_Name Pilot_Workload  \
# 0  ...         8386.0             CXF  Fransisco Hazeldine              1
# 1  ...         8758.0             YCO      Marla Parsonage              1
# 2  ...         8386.0             GNB         Rhonda Amber              1
# 3  ...         8462.0             YND       Kacie Commucci              1
# 4  ...         8462.0             SEE          Ebonee Tree              1
#
#    Flight_Status Is_Flight_Delayed              Delay_Cause  \
# 0        On Time                 0                 No Delay
# 1        On Time                 0                 No Delay
# 2        On Time                 0                 No Delay
# 3        Delayed                 1  Operational / Technical
# 4        On Time                 0                 No Delay
#
#        Delay_Severity  Operational_Risk    Flight_Type
# 0           No Impact          Low Risk  International
# 1           No Impact          Low Risk  International
# 2           No Impact          Low Risk  International
# 3  Operational Impact       Medium Risk  International
# 4           No Impact          Low Risk  International
#
# [5 rows x 31 columns]

# %% [markdown]
# Data Structure

# %%
df.info()
df.describe(include="all")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98619 entries, 0 to 98618
# Data columns (total 31 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Passenger_ID          98619 non-null  object
#  1   First_Name            98619 non-null  object
#  2   Last_Name             98619 non-null  object
#  3   Passenger_Full_Name   98619 non-null  object
#  4   Gender                98619 non-null  object
#  5   Age                   98619 non-null  int64
#  6   Age_Group             98619 non-null  object
#  7   Nationality           98619 non-null  object
#  8   Airport_Name          98619 non-null  object
#  9   Airport_Country_Code  98619 non-null  object
#  10  Country_Name          98619 non-null  object
#  11  Airport_Continent     98619 non-null  object
#  12  Continents            98619 non-null  object
#  13  Airport_Location      98619 non-null  object
#  14  Airport_Congestion    98619 non-null  int64
#  15  Departure_Date        59658 non-null  object
#  16  Departure_Year        59658 non-null  float64
#  17  Departure_Month       59658 non-null  float64
#  18  Departure_Day         59658 non-null  float64
#  19  Departure_DayOfWeek   59658 non-null  object
#  20  Monthly_Traffic       59658 non-null  float64
#  21  Weekly_Traffic        59658 non-null  float64
#  22  Arrival_Airport       98619 non-null  object
#  23  Pilot_Name            98619 non-null  object
#  24  Pilot_Workload        98619 non-null  int64
#  25  Flight_Status         98619 non-null  object
#  26  Is_Flight_Delayed     98619 non-null  int64
#  27  Delay_Cause           98619 non-null  object
#  28  Delay_Severity        98619 non-null  object
#  29  Operational_Risk      98619 non-null  object
#  30  Flight_Type           98619 non-null  object
# dtypes: float64(5), int64(4), object(22)
# memory usage: 23.3+ MB
#        Passenger_ID First_Name Last_Name Passenger_Full_Name Gender  \
# count         98619      98619     98619               98619  98619
# unique        98619       8437     41658               98610      2
# top          8JYEcz       Gale    Dyball   Auberon Alennikov   Male
# freq              1         37        17                   2  49598
# mean            NaN        NaN       NaN                 NaN    NaN
# std             NaN        NaN       NaN                 NaN    NaN
# min             NaN        NaN       NaN                 NaN    NaN
# 25%             NaN        NaN       NaN                 NaN    NaN
# 50%             NaN        NaN       NaN                 NaN    NaN
# 75%             NaN        NaN       NaN                 NaN    NaN
# max             NaN        NaN       NaN                 NaN    NaN
#
#                  Age       Age_Group Nationality       Airport_Name  \
# count   98619.000000           98619       98619              98619
# unique           NaN               5         240               9062
# top              NaN  Senior Citizen       China  San Pedro Airport
# freq             NaN           38376       18317                 43
# mean       45.504021             NaN         NaN                NaN
# std        25.929849             NaN         NaN                NaN
# min         1.000000             NaN         NaN                NaN
# 25%        23.000000             NaN         NaN                NaN
# 50%        46.000000             NaN         NaN                NaN
# 75%        68.000000             NaN         NaN                NaN
# max        90.000000             NaN         NaN                NaN
#
#        Airport_Country_Code  ... Weekly_Traffic Arrival_Airport  \
# count                 98619  ...   59658.000000           98619
# unique                  235  ...            NaN            9024
# top                      US  ...            NaN               0
# freq                  22104  ...            NaN             873
# mean                    NaN  ...    8532.060445             NaN
# std                     NaN  ...     279.301585             NaN
# min                     NaN  ...    7928.000000             NaN
# 25%                     NaN  ...    8386.000000             NaN
# 50%                     NaN  ...    8563.000000             NaN
# 75%                     NaN  ...    8772.000000             NaN
# max                     NaN  ...    8789.000000             NaN
#
#            Pilot_Name Pilot_Workload  Flight_Status Is_Flight_Delayed  \
# count           98619   98619.000000          98619       98619.00000
# unique          98605            NaN              3               NaN
# top     Valeda Pratty            NaN      Cancelled               NaN
# freq                2            NaN          32942               NaN
# mean              NaN       1.000284            NaN           0.66694
# std               NaN       0.016848            NaN           0.47131
# min               NaN       1.000000            NaN           0.00000
# 25%               NaN       1.000000            NaN           0.00000
# 50%               NaN       1.000000            NaN           1.00000
# 75%               NaN       1.000000            NaN           1.00000
# max               NaN       2.000000            NaN           1.00000
#
#                Delay_Cause      Delay_Severity  Operational_Risk  \
# count                98619               98619             98619
# unique                   3                   2                 3
# top     Weather / Climatic  Operational Impact         High Risk
# freq                 32942               65773             32942
# mean                   NaN                 NaN               NaN
# std                    NaN                 NaN               NaN
# min                    NaN                 NaN               NaN
# 25%                    NaN                 NaN               NaN
# 50%                    NaN                 NaN               NaN
# 75%                    NaN                 NaN               NaN
# max                    NaN                 NaN               NaN
#
#           Flight_Type
# count           98619
# unique              2
# top     International
# freq            96844
# mean              NaN
# std               NaN
# min               NaN
# 25%               NaN
# 50%               NaN
# 75%               NaN
# max               NaN
#
# [11 rows x 31 columns]

# %% [markdown]
# Temporal Dataset

# %%
df_time = df.dropna(
subset=["Departure_Month",
        "Departure_DayOfWeek"])

# %% [markdown]
# Creating Label Function

# %%
def add_labels(ax,total=None):
    for p in ax.patches:
        value=p.get_height()
        if total:
            label=f"{int(value)} ({value/total*100:.1f}%)"
        else:
            label=f"{int(value)}"

        ax.annotate(
            label,
            (p.get_x()+p.get_width()/2,value),
            ha="center"
        )

# %% [markdown]
# PASSANGER'S AGE ANALYSIS

# %% [markdown]
# Age Distribition

# %%
sns.histplot(
df["Age"],
bins=40,
kde=True,
color="teal")

plt.title("Overall Passenger Age Distribution")
plt.show()

# %% [markdown]
# Age Group Distribution

# %%
age_counts=df["Age_Group"].value_counts()

plt.pie(
age_counts,
labels=age_counts.index,
autopct="%1.1f%%",
colors=sns.color_palette("Set2"),
wedgeprops={"width":0.4})

plt.title("Passenger Age Group Share")
plt.show()

# %% [markdown]
# PASSENGER DEMOGRAPHICS

# %% [markdown]
# Gender Distribution

# %%
ax=sns.countplot(
x="Gender",
data=df,
palette="Set3",
hue='Gender',
legend=False)

plt.title("Gender Distribution")
add_labels(ax,len(df))
plt.show()

# %% [markdown]
# Nationality Distribution

# %%
top_nat=df["Nationality"].value_counts().head(10)

top_nat.plot(
kind="barh",
color="cornflowerblue")

plt.title("Top Passenger Nationalities")
plt.show()

# %% [markdown]
# AIRPORT & TRAFFIC ANALYSIS

# %% [markdown]
# Busiest Airports

# %%
top_airports = (
    df["Airport_Name"]
    .value_counts()
    .head(10)
    .reset_index()
)

top_airports.columns = ["Airport_Name", "Flight_Count"]

sns.barplot(
    data=top_airports,
    x="Flight_Count",
    y="Airport_Name",
    hue="Airport_Name",
    palette="coolwarm",
    legend=False
)

plt.title("Top Busiest Airports")
plt.show()

# %% [markdown]
# Traffic Share by Continent

# %%
df["Airport_Continent"].value_counts().plot(
kind="pie",
autopct="%1.1f%%",
colormap="Pastel1")

plt.title("Global Traffic Share")
plt.ylabel("")
plt.show()

# %% [markdown]
# ENGINEERED FEATURE ANALYSIS

# %% [markdown]
# Airport Congestion Distribution

# %%
sns.histplot(
df["Airport_Congestion"],
bins=30,
color="orange")

plt.title("Airport Congestion Distribution")
plt.show()

# %% [markdown]
# FLIGHT STATUS

# %% [markdown]
# Domestic VS International

# %%
ax=sns.countplot(
x="Flight_Type",
data=df,
palette="Set2",
hue='Flight_Type',
legend=False)

plt.title("Flight Type Distribution")
add_labels(ax,len(df))
plt.show()

# %% [markdown]
# Traffic Load Comparison

# %%
sns.violinplot(
    x="Flight_Type",
    y="Monthly_Traffic",
    data=df,
    palette="coolwarm",
    hue='Flight_Type',
    legend=False,
    inner="quartile"
)
# Out:
# <Axes: xlabel='Flight_Type', ylabel='Monthly_Traffic'>

# %% [markdown]
# TEMPORAL TRAFFIC

# %% [markdown]
# Monthly Flights

# %%
month_counts=df_time["Departure_Month"].value_counts().sort_index()

sns.lineplot(
x=month_counts.index,
y=month_counts.values,
marker="o",
color="green")

plt.title("Monthly Flight Trend")
plt.show()

# %% [markdown]
# Weekly Flights

# %%
ax=sns.countplot(
x="Departure_DayOfWeek",
data=df_time,
palette="cubehelix",
hue='Departure_DayOfWeek',
legend=False)

plt.title("Flights by Weekday")
add_labels(ax)
plt.show()

# %% [markdown]
# ### Week 3 Insights
#
# - Passenger demand dominated by working-age travellers.
# - Hub airports experience high congestion.
# - International operations show heavier traffic loads.
# - Traffic demand varies seasonally.
